# %%
import seaborn as sns

import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

import torch
from torch import nn
from torchsummary import summary
from torch.autograd import Variable

import scikitplot as skplt

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
iris = sns.load_dataset('iris')
sns.set(style="ticks", color_codes=True)

# %%
g = sns.pairplot(iris, hue='species')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
classes = {'setosa': 0, 'versicolor': 1, 'virginica': 2}

# %%
X = iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].values

# %%
y = iris['species'].apply(lambda x: classes[x]).values

# %%
X_train_array, X_test_array, y_train_array, y_test_array = train_test_split(X, y, test_size=0.33, random_state=0)

# y_train_array = np.expand_dims(y_train_array, axis=0)
# y_test_array = np.expand_dims(y_test_array, axis=0)

print(X_train_array[:5], np.shape(X_train_array))

print(y_train_array[:5], np.shape(y_train_array))

print(X_test_array[:5], np.shape(X_test_array))

print(y_test_array[:5], np.shape(y_test_array))
# Out:
# [[5.6 2.5 3.9 1.1]
#  [7.7 3.  6.1 2.3]
#  [6.3 3.3 4.7 1.6]
#  [5.5 2.4 3.8 1.1]
#  [6.3 2.7 4.9 1.8]] (100, 4)
# [1 2 1 1 2] (100,)
# [[5.8 2.8 5.1 2.4]
#  [6.  2.2 4.  1. ]
#  [5.5 4.2 1.4 0.2]
#  [7.3 2.9 6.3 1.8]
#  [5.  3.4 1.5 0.2]] (50, 4)
# [2 1 0 2 0] (50,)

# %%
iris_model = nn.Sequential(
    torch.nn.Linear(4,10),
    torch.nn.SELU(),
    torch.nn.Linear(10,3),
    torch.nn.Softmax(dim=1)
)

print(iris_model)
# Out:
# Sequential(
#   (0): Linear(in_features=4, out_features=10, bias=True)
#   (1): SELU()
#   (2): Linear(in_features=10, out_features=3, bias=True)
#   (3): Softmax(dim=1)
# )

# %%
summary(iris_model, (1,4))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 10]              50
#               SELU-2                [-1, 1, 10]               0
#             Linear-3                 [-1, 1, 3]              33
#            Softmax-4                 [-1, 1, 3]               0
# ================================================================
# Total params: 83
# Trainable params: 83
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------

# %%
X_train = Variable(
    torch.from_numpy(X_train_array).float()
)
y_train = Variable(
    torch.from_numpy(y_train_array).long()
)
X_test = Variable(
    torch.from_numpy(X_test_array).float()
)
y_test = Variable(
    torch.from_numpy(y_test_array).long()
)

# %%
y_train
# Out:
# tensor([1, 2, 1, 1, 2, 2, 2, 2, 1, 2, 1, 0, 2, 1, 1, 1, 1, 2, 0, 0, 2, 1, 0, 0,
#         1, 0, 2, 1, 0, 1, 2, 1, 0, 2, 2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 2, 2, 0, 0,
#         2, 0, 0, 0, 1, 2, 2, 0, 0, 0, 1, 1, 0, 0, 1, 0, 2, 1, 2, 1, 0, 2, 0, 2,
#         0, 0, 2, 0, 2, 1, 1, 1, 2, 2, 1, 1, 0, 1, 2, 2, 0, 1, 1, 1, 1, 0, 0, 0,
#         2, 1, 2, 0])

# %% [markdown]
# ## Training

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(
    iris_model.parameters(), lr=0.01
)
for epoch in range(1000):
    optimizer.zero_grad()
    out = iris_model(X_train)
    loss = criterion(out, y_train)
    loss.backward()
    optimizer.step()
    if epoch % 10 == 0:
        print('number of epoch:', epoch, 'loss:', loss)
# Out:
# number of epoch: 0 loss: tensor(0.5727, grad_fn=<NllLossBackward>)
# number of epoch: 10 loss: tensor(0.5865, grad_fn=<NllLossBackward>)
# number of epoch: 20 loss: tensor(0.5721, grad_fn=<NllLossBackward>)
# number of epoch: 30 loss: tensor(0.5687, grad_fn=<NllLossBackward>)
# number of epoch: 40 loss: tensor(0.5816, grad_fn=<NllLossBackward>)
# number of epoch: 50 loss: tensor(0.5830, grad_fn=<NllLossBackward>)
# number of epoch: 60 loss: tensor(0.5796, grad_fn=<NllLossBackward>)
# number of epoch: 70 loss: tensor(0.5660, grad_fn=<NllLossBackward>)
# number of epoch: 80 loss: tensor(0.5706, grad_fn=<NllLossBackward>)
# number of epoch: 90 loss: tensor(0.5663, grad_fn=<NllLossBackward>)
# number of epoch: 100 loss: tensor(0.5667, grad_fn=<NllLossBackward>)
# number of epoch: 110 loss: tensor(0.5666, grad_fn=<NllLossBackward>)
# number of epoch: 120 loss: tensor(0.5665, grad_fn=<NllLossBackward>)
# number of epoch: 130 loss: tensor(0.5662, grad_fn=<NllLossBackward>)
# number of epoch: 140 loss: tensor(0.5663, grad_fn=<NllLossBackward>)
# number of epoch: 150 loss: tensor(0.5658, grad_fn=<NllLossBackward>)
# number of epoch: 160 loss: tensor(0.5657, grad_fn=<NllLossBackward>)
# number of epoch: 170 loss: tensor(0.5659, grad_fn=<NllLossBackward>)
# number of epoch: 180 loss: tensor(0.5663, grad_fn=<NllLossBackward>)
# number of epoch: 190 loss: tensor(0.5669, grad_fn=<NllLossBackward>)
# number of epoch: 200 loss: tensor(0.5717, grad_fn=<NllLossBackward>)
# number of epoch: 210 loss: tensor(0.5814, grad_fn=<NllLossBackward>)
# number of epoch: 220 loss: tensor(0.5655, grad_fn=<NllLossBackward>)
# number of epoch: 230 loss: tensor(0.5658, grad_fn=<NllLossBackward>)
# number of epoch: 240 loss: tensor(0.5697, grad_fn=<NllLossBackward>)
# number of epoch: 250 loss: tensor(0.5644, grad_fn=<NllLossBackward>)
# number of epoch: 260 loss: tensor(0.5644, grad_fn=<NllLossBackward>)
# number of epoch: 270 loss: tensor(0.5642, grad_fn=<NllLossBackward>)
# number of epoch: 280 loss: tensor(0.5694, grad_fn=<NllLossBackward>)
# number of epoch: 290 loss: tensor(0.5758, grad_fn=<NllLossBackward>)
# number of epoch: 300 loss: tensor(0.5752, grad_fn=<NllLossBackward>)
# number of epoch: 310 loss: tensor(0.5725, grad_fn=<NllLossBackward>)
# number of epoch: 320 loss: tensor(0.5642, grad_fn=<NllLossBackward>)
# number of epoch: 330 loss: tensor(0.5695, grad_fn=<NllLossBackward>)
# number of epoch: 340 loss: tensor(0.5651, grad_fn=<NllLossBackward>)
# number of epoch: 350 loss: tensor(0.5638, grad_fn=<NllLossBackward>)
# number of epoch: 360 loss: tensor(0.5887, grad_fn=<NllLossBackward>)
# number of epoch: 370 loss: tensor(0.5645, grad_fn=<NllLossBackward>)
# number of epoch: 380 loss: tensor(0.5642, grad_fn=<NllLossBackward>)
# number of epoch: 390 loss: tensor(0.5643, grad_fn=<NllLossBackward>)
# number of epoch: 400 loss: tensor(0.5641, grad_fn=<NllLossBackward>)
# number of epoch: 410 loss: tensor(0.5636, grad_fn=<NllLossBackward>)
# number of epoch: 420 loss: tensor(0.5751, grad_fn=<NllLossBackward>)
# number of epoch: 430 loss: tensor(0.5636, grad_fn=<NllLossBackward>)
# number of epoch: 440 loss: tensor(0.5870, grad_fn=<NllLossBackward>)
# number of epoch: 450 loss: tensor(0.5649, grad_fn=<NllLossBackward>)
# number of epoch: 460 loss: tensor(0.5653, grad_fn=<NllLossBackward>)
# number of epoch: 470 loss: tensor(0.5725, grad_fn=<NllLossBackward>)
# number of epoch: 480 loss: tensor(0.5703, grad_fn=<NllLossBackward>)
# number of epoch: 490 loss: tensor(0.5817, grad_fn=<NllLossBackward>)
# number of epoch: 500 loss: tensor(0.5647, grad_fn=<NllLossBackward>)
# number of epoch: 510 loss: tensor(0.5660, grad_fn=<NllLossBackward>)
# number of epoch: 520 loss: tensor(0.5639, grad_fn=<NllLossBackward>)
# number of epoch: 530 loss: tensor(0.5635, grad_fn=<NllLossBackward>)
# number of epoch: 540 loss: tensor(0.5657, grad_fn=<NllLossBackward>)
# number of epoch: 550 loss: tensor(0.5806, grad_fn=<NllLossBackward>)
# number of epoch: 560 loss: tensor(0.5634, grad_fn=<NllLossBackward>)
# number of epoch: 570 loss: tensor(0.5705, grad_fn=<NllLossBackward>)
# number of epoch: 580 loss: tensor(0.5635, grad_fn=<NllLossBackward>)
# number of epoch: 590 loss: tensor(0.5716, grad_fn=<NllLossBackward>)
# number of epoch: 600 loss: tensor(0.5653, grad_fn=<NllLossBackward>)
# number of epoch: 610 loss: tensor(0.5707, grad_fn=<NllLossBackward>)
# number of epoch: 620 loss: tensor(0.5642, grad_fn=<NllLossBackward>)
# number of epoch: 630 loss: tensor(0.5661, grad_fn=<NllLossBackward>)
# number of epoch: 640 loss: tensor(0.5734, grad_fn=<NllLossBackward>)
# number of epoch: 650 loss: tensor(0.5760, grad_fn=<NllLossBackward>)
# number of epoch: 660 loss: tensor(0.5665, grad_fn=<NllLossBackward>)
# number of epoch: 670 loss: tensor(0.5701, grad_fn=<NllLossBackward>)
# number of epoch: 680 loss: tensor(0.5736, grad_fn=<NllLossBackward>)
# number of epoch: 690 loss: tensor(0.5661, grad_fn=<NllLossBackward>)
# number of epoch: 700 loss: tensor(0.5678, grad_fn=<NllLossBackward>)
# number of epoch: 710 loss: tensor(0.5723, grad_fn=<NllLossBackward>)
# number of epoch: 720 loss: tensor(0.5653, grad_fn=<NllLossBackward>)
# number of epoch: 730 loss: tensor(0.5682, grad_fn=<NllLossBackward>)
# number of epoch: 740 loss: tensor(0.5718, grad_fn=<NllLossBackward>)
# number of epoch: 750 loss: tensor(0.5668, grad_fn=<NllLossBackward>)
# number of epoch: 760 loss: tensor(0.5687, grad_fn=<NllLossBackward>)
# number of epoch: 770 loss: tensor(0.5713, grad_fn=<NllLossBackward>)
# number of epoch: 780 loss: tensor(0.5661, grad_fn=<NllLossBackward>)
# number of epoch: 790 loss: tensor(0.5686, grad_fn=<NllLossBackward>)
# number of epoch: 800 loss: tensor(0.5679, grad_fn=<NllLossBackward>)
# number of epoch: 810 loss: tensor(0.5691, grad_fn=<NllLossBackward>)
# number of epoch: 820 loss: tensor(0.5739, grad_fn=<NllLossBackward>)
# number of epoch: 830 loss: tensor(0.5648, grad_fn=<NllLossBackward>)
# number of epoch: 840 loss: tensor(0.5653, grad_fn=<NllLossBackward>)
# number of epoch: 850 loss: tensor(0.5709, grad_fn=<NllLossBackward>)
# number of epoch: 860 loss: tensor(0.5631, grad_fn=<NllLossBackward>)
# number of epoch: 870 loss: tensor(0.5727, grad_fn=<NllLossBackward>)
# number of epoch: 880 loss: tensor(0.5710, grad_fn=<NllLossBackward>)
# number of epoch: 890 loss: tensor(0.5720, grad_fn=<NllLossBackward>)
# number of epoch: 900 loss: tensor(0.5657, grad_fn=<NllLossBackward>)
# number of epoch: 910 loss: tensor(0.5713, grad_fn=<NllLossBackward>)
# number of epoch: 920 loss: tensor(0.5633, grad_fn=<NllLossBackward>)
# number of epoch: 930 loss: tensor(0.5661, grad_fn=<NllLossBackward>)
# number of epoch: 940 loss: tensor(0.5762, grad_fn=<NllLossBackward>)
# number of epoch: 950 loss: tensor(0.5701, grad_fn=<NllLossBackward>)
# number of epoch: 960 loss: tensor(0.5729, grad_fn=<NllLossBackward>)
# number of epoch: 970 loss: tensor(0.5659, grad_fn=<NllLossBackward>)
# number of epoch: 980 loss: tensor(0.5665, grad_fn=<NllLossBackward>)
# number of epoch: 990 loss: tensor(0.5674, grad_fn=<NllLossBackward>)

# %%
fig, ax = plt.subplots(figsize=[5,5])

y_pred = iris_model(X_test).detach().numpy()
skplt.metrics.plot_confusion_matrix(
    y_test,
    y_pred.argmax(axis=1),
    normalize=True,
    ax=ax
)
labels = ['setosa', 'versicolor', 'virginica']
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)
# Out:
# [Text(0, 0, 'setosa'), Text(0, 1, 'versicolor'), Text(0, 2, 'virginica')]
